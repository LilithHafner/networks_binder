# %%
f(m, hdd, cs) = [rand(rand(cs), rand(hdd)) for _ in 1:m]
# Out:
# f (generic function with 1 method)

# %%
g = @timed f(10^6, 2:8, [1:10, 1:5, 6:10]);

# %%
g.time/length(g.value)*1e9
# Out:
# 241.333681

# %%
g.time/sum(length.(g.value))*1e9
# Out:
# 48.290601415219406

# %%
empty!(Out); GC.gc()

# %%
g.time
# Out:
# 0.241333681
